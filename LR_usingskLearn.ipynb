# %% [markdown]
# <a href="https://colab.research.google.com/github/sim27in/ml-algos-all/blob/main/LR_usingskLearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
np.random.seed(42)
X = np.random.rand(50, 1) * 100

# %%
y = 3.2 * X + np.random.rand(50,1) * 20

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color = 'blue', label = 'Data pts')
plt.plot(X, y_pred, color = 'red', label = 'Regression Line')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
print("Model Coefficient: " + str(model.coef_))
print("Model Intercept: " + str(model.intercept_))
# Out:
# Model Coefficient: [[3.21321533]]
# Model Intercept: [9.2994485]
